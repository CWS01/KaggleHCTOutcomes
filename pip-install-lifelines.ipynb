# %% [markdown]
# # WHL Files to Pip Install Competition Metric
# There is a discussion explaining how to use these WHL files [here][1]. Below is a quick summary:
#
# To compute the competition metric in your notebook, attached this notebook (which you are reading) which contains WHL files (because we need to pip install with internet off to be able to submit to comp). Also attach Kaggle's metic notebook [here][2]. Then add the following code in the first cell:
#
#     !pip install /kaggle/input/pip-install-lifelines/autograd-1.7.0-py3-none-any.whl
#     !pip install /kaggle/input/pip-install-lifelines/autograd-gamma-0.5.0.tar.gz
#     !pip install /kaggle/input/pip-install-lifelines/interface_meta-1.3.0-py3-none-any.whl
#     !pip install /kaggle/input/pip-install-lifelines/formulaic-1.0.2-py3-none-any.whl
#     !pip install /kaggle/input/pip-install-lifelines/lifelines-0.30.0-py3-none-any.whl
#
# Afterward to compute the competition metric, run this code where preds are your oof predictions:
#
#     from metric import score
#     y_true = train[["ID","efs","efs_time","race_group"]].copy()
#     y_pred = train[["ID"]].copy()
#     y_pred["prediction"] = preds
#     m = score(y_true.copy(), y_pred.copy(), "ID")
#     print(f"CV Score = {m}")
#
#
# [1]: https://www.kaggle.com/competitions/equity-post-HCT-survival-predictions/discussion/550003
# [2]: https://www.kaggle.com/code/metric/eefs-concordance-index

# %%
# !pip download lifelines
# Out:
# Collecting lifelines
#   Downloading lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting numpy>=1.14.0 (from lifelines)
#   Downloading numpy-2.2.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 940.7 kB/s eta 0:00:00 0:00:01
# Collecting scipy>=1.7.0 (from lifelines)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.2 MB/s eta 0:00:00
# Collecting pandas>=2.1 (from lifelines)
#   Downloading pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.7 MB/s eta 0:00:00
# Collecting matplotlib>=3.0 (from lifelines)
#   Downloading matplotlib-3.10.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting autograd>=1.5 (from lifelines)
#   Downloading autograd-1.7.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting autograd-gamma>=0.3 (from lifelines)
#   Downloading autograd-gamma-0.5.0.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting formulaic>=0.2.2 (from lifelines)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.2.0 (from formulaic>=0.2.2->lifelines)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.0 (from formulaic>=0.2.2->lifelines)
#   Downloading wrapt-1.17.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0->lifelines)
#   Downloading contourpy-1.3.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0->lifelines)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0->lifelines)
#   Downloading fonttools-4.55.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 5.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0->lifelines)
#   Downloading kiwisolver-1.4.8-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.0->lifelines)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pillow>=8 (from matplotlib>=3.0->lifelines)
#   Downloading pillow-11.0.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.0->lifelines)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.0->lifelines)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=2.1->lifelines)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.1->lifelines)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.0->lifelines)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading lifelines-0.30.0-py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 4.4 MB/s eta 0:00:0000:0100:01
# Downloading autograd-1.7.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 2.0 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 3.9 MB/s eta 0:00:00
# Downloading matplotlib-3.10.0-cp312-cp312-macosx_10_13_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 7.5 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.2.1-cp312-cp312-macosx_10_13_x86_64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 8.6 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.14.1-cp312-cp312-macosx_10_13_x86_64.whl (39.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.1/39.1 MB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.3.1-cp312-cp312-macosx_10_13_x86_64.whl (271 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 kB 5.9 MB/s eta 0:00:00:00:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp312-cp312-macosx_10_13_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 6.8 MB/s eta 0:00:0000:0100:01
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading kiwisolver-1.4.8-cp312-cp312-macosx_10_13_x86_64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 3.1 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.4 MB/s eta 0:00:00
# Downloading pillow-11.0.0-cp312-cp312-macosx_10_13_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 7.7 MB/s eta 0:00:0000:0100:01m
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 4.5 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 5.4 MB/s eta 0:00:00:00:01
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 6.7 MB/s eta 0:00:00ta 0:00:01
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 7.3 MB/s eta 0:00:00ta 0:00:01
# Downloading wrapt-1.17.0-py3-none-any.whl (23 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Saved ./lifelines-0.30.0-py3-none-any.whl
# Saved ./autograd-1.7.0-py3-none-any.whl
# Saved ./autograd-gamma-0.5.0.tar.gz
# Saved ./formulaic-1.1.1-py3-none-any.whl
# Saved ./matplotlib-3.10.0-cp312-cp312-macosx_10_13_x86_64.whl
# Saved ./numpy-2.2.1-cp312-cp312-macosx_10_13_x86_64.whl
# Saved ./pandas-2.2.3-cp312-cp312-macosx_10_9_x86_64.whl
# Saved ./scipy-1.14.1-cp312-cp312-macosx_10_13_x86_64.whl
# Saved ./contourpy-1.3.1-cp312-cp312-macosx_10_13_x86_64.whl
# Saved ./cycler-0.12.1-py3-none-any.whl
# Saved ./fonttools-4.55.3-cp312-cp312-macosx_10_13_x86_64.whl
# Saved ./interface_meta-1.3.0-py3-none-any.whl
# Saved ./kiwisolver-1.4.8-cp312-cp312-macosx_10_13_x86_64.whl
# Saved ./packaging-24.2-py3-none-any.whl
# Saved ./pillow-11.0.0-cp312-cp312-macosx_10_13_x86_64.whl
# Saved ./pyparsing-3.2.0-py3-none-any.whl
# Saved ./python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# Saved ./pytz-2024.2-py2.py3-none-any.whl
# Saved ./typing_extensions-4.12.2-py3-none-any.whl
# Saved ./tzdata-2024.2-py2.py3-none-any.whl
# Saved ./wrapt-1.17.0-py3-none-any.whl
# Saved ./six-1.17.0-py2.py3-none-any.whl
# Successfully downloaded lifelines autograd autograd-gamma formulaic matplotlib numpy pandas scipy contourpy cycler fonttools interface-meta kiwisolver packaging pillow pyparsing python-dateutil pytz typing-extensions tzdata wrapt six

# %%
# !pip install import_ipynb

import import_ipynb
from metric import score
# Out:
# Collecting import_ipynb
#   Downloading import_ipynb-0.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: IPython in /opt/anaconda3/lib/python3.12/site-packages (from import_ipynb) (8.25.0)
# Requirement already satisfied: nbformat in /opt/anaconda3/lib/python3.12/site-packages (from import_ipynb) (5.9.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from IPython->import_ipynb) (4.8.0)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.12/site-packages (from nbformat->import_ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.12/site-packages (from nbformat->import_ipynb) (4.19.2)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/lib/python3.12/site-packages (from nbformat->import_ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.10.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->IPython->import_ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-core->nbformat->import_ipynb) (3.10.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->IPython->import_ipynb) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->IPython->import_ipynb) (0.2.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from asttokens->stack-data->IPython->import_ipynb) (1.16.0)
# Downloading import_ipynb-0.2-py3-none-any.whl (4.0 kB)
# Installing collected packages: import_ipynb
# Successfully installed import_ipynb-0.2
